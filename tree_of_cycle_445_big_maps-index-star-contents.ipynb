# %% [markdown]
# # Analysis of the tree of the commit belonging to block level 2,056,194
# ### which is the second block of cycle 445 (created on Jan 23, 2022)
#
# ##### zoom on this set of nodes: `/data/big_maps/index/*/contents`

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from custom_plot_tools import plot_4_vertical_bubble_histo, plot_grid_bubble_histo

# %% [markdown]
# ### Summary
# ```
# Number of objects: 2,810,738 (a.k.a. pack file entries). Breakdown:
# -   0%          0 contents (a.k.a. blobs);
# -   1%     40,777 nodes (a.k.a. root inodes, directories);
# -  99%  2,769,961 hidden nodes (a.k.a. non-root inodes).
#
# Number of bytes: 1,077,969,426. First breakdown:
# -   0%             0B in contents;
# -   1%     8,527,567B in nodes;
# -  99% 1,069,441,859B in hidden nodes.
#
# Second breakdown:
# -   8%  89,943,616B used by the 32 byte hash that prefixes all objects;
# -  76% 818,020,255B used in hard coded steps (a.k.a. direct step) (a step is a file name or a directory name, it is a step in a path);
# -  16% 170,005,555B elsewhere.
#
# Number of steps: 13,890,632 (i.e. number of node children). Breakdown:
# -  91% 12,584,927 by direct references (i.e. parent records hard coded step);
# -   9%  1,305,705 by indirect references (i.e. parent records "dict" id),
# ```

# %% [markdown]
# 💡 The steps all have length 65 here. They represent 818MB out of the 2.5GB that the full tree weighs.
# If there are many duplicates, something could maybe be done.
#
# 💡 The indirect steps might be cluttering the dict.

# %% [markdown]
# ### Objects Kind
#
# The following plot groups the objects into 10 categories:
# - 4 categories for contents, depending on their size,
# - 5 categories for inodes, depending on the size of the node they belong to,
# - 1 extra category for inodes that appear in several categories at once. (No need to overthink that category)
#
# __Each column in such a graph sum to 100%__.

# %%
plot_4_vertical_bubble_histo('/tmp/tree_of_cycle_445_big_maps-index-star-contents.ipynb.csv',
                             'ekind')

# %% [markdown]
# 💡 The 62 very large nodes weigh almost 1GB, while the full tree weighs 2.5GB.

# %% [markdown]
# ### Objects Distance to Commit
#
# The following plot groups the objects into 5 categories, depending on how old they are.
#
# For instance, `<1 cycle away` implies that the objects in that row are less than 1 cycle away from
# the commit in the pack file (i.e. less than 8200 blocks away, less than 3 days away).
#
# The `4 or more cycles away` row is the largest because most objects of a tree are at the beginning of the file, in the "snapshot import" section.

# %%
plot_4_vertical_bubble_histo('/tmp/tree_of_cycle_445_big_maps-index-star-contents.ipynb.csv',
                             'area_distance_from_origin')
