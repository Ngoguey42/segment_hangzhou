# %% [markdown]
# # Analysis of the Irmin tree of block level 2,056,194
# ### which is the second block of cycle 445 (created on Jan 23, 2022)
#
# ##### zoom on this node: `/data/big_maps/index/*/contents`

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from custom_plot_tools import plot_4_vertical_bubble_histo, plot_grid_bubble_histo

# %% [markdown]
# ### Summary
# ```
# Number of bytes: 1,077,969,426. Breakdown:
#   -   8%  89,943,616B in 32 byte hash of objects,
#   -  76% 818,020,255B in hard coded steps (a.k.a. direct step),
#   -  16% 170,005,555B elsewhere (i.e. length segment + value segment).
#
# Number of objects: 2,810,738 (a.k.a. pack file entries). Breakdown:
#   -   0%          0 contents (a.k.a. blobs),
#   -   1%     40,777 nodes (a.k.a. root inodes, directory),
#   -  99%  2,769,961 hidden nodes (a.k.a. non-root inodes).
#
# Number of steps: 13,890,632 (i.e. number of children in the nodes). Breakdown:
#   -  91% 12,584,927 by direct references (i.e. parent records hard coded step),
#   -   9%  1,305,705 by indirect references (i.e. parent records "dict" id),
# ```

# %% [markdown]
# 💡 The steps all have length 65 here. They represent 818MB out of the 2.5GB that the full tree weighs.

# %% [markdown]
# ### Objects Kind
#
# The following plot groups the objects into 10 categories:
# - 4 categories for contents, depending on their size,
# - 5 categories for inodes, depending on the size of the node they belong to,
# - 1 extra category for inodes that appear in several categories at once.

# %%
plot_4_vertical_bubble_histo('/tmp/tree_of_cycle_445_big_maps-index-star-contents.ipynb.csv',
                           'ekind')

# %% [markdown]
# 💡 The 62 very large nodes weigh almost 1GB, while the full tree weighs 2.5GB.

# %% [markdown]
# ### Objects Distance to Commit
#
# The following plot groups the objects into 5 categories, depending on their distance to the commit of the tree.
# For instance, `<1 cycle` implies that the objects in that row are less than 1 cycle away from the commit being analysed (i.e. less than 8200 blocks away, less than 3 days away).

# %%
plot_4_vertical_bubble_histo('/tmp/tree_of_cycle_445_big_maps-index-star-contents.ipynb.csv',
                           'area_distance_from_origin')

# %% [markdown]
# ### toto
#
# toto

# %%
plot_grid_bubble_histo('/tmp/tree_of_cycle_445_big_maps-index-star-contents.ipynb.csv',
                       'bytes', 'area_distance_from_origin', 'ekind')

# %%
plot_grid_bubble_histo('/tmp/tree_of_cycle_445_big_maps-index-star-contents.ipynb.csv',
                       'count', 'area_distance_from_origin', 'ekind')

# %% [markdown]
# ### toto
#
# toto

# %%
plot_grid_bubble_histo('/tmp/tree_of_cycle_445_big_maps-index-star-contents.ipynb.csv',
                       'bytes', 'area_distance_from_origin', 'path3')

# %%
plot_grid_bubble_histo('/tmp/tree_of_cycle_445_big_maps-index-star-contents.ipynb.csv',
                       'count', 'area_distance_from_origin', 'path3')

# %% [markdown]
# ### toto
#
# toto

# %%
plot_grid_bubble_histo('/tmp/tree_of_cycle_445_big_maps-index-star-contents.ipynb.csv',
                       'bytes', 'ekind', 'path3')

# %%
plot_grid_bubble_histo('/tmp/tree_of_cycle_445_big_maps-index-star-contents.ipynb.csv',
                       'count', 'ekind', 'path3')
