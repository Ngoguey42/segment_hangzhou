# %% [markdown]
# # Analysis of the tree of the commit belonging to block level 2,056,194
# ### which is the second block of cycle 445 (created on Jan 23, 2022)
#
# ##### zoom on this set of nodes: `/data/contracts/index/*/manager`

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from custom_plot_tools import plot_vertical_bubble_histo, plot_grid_bubble_histo

# %% [markdown]
# ### Summary
# ```
# Number of objects: 1,920,055 (a.k.a. pack file entries). Breakdown:
# - 100%  1,920,055 contents (a.k.a. blobs);
# -   0%          0 nodes (a.k.a. root inodes, directories);
# -   0%          0 hidden nodes (a.k.a. non-root inodes).
#
# Number of bytes: 118,922,714. First breakdown:
# - 100%   118,922,714B in contents;
# -   0%             0B in nodes;
# -   0%             0B in hidden nodes.
#
# Second breakdown:
# -  52%  61,441,760B used by the 32 byte hash that prefixes all objects;
# -   0%           0B used in hard coded steps (a.k.a. direct step) (a step is a file name or a directory name, it is a step in a path);
# -  48%  57,480,954B elsewhere.
#
# Number of steps: 0 (i.e. number of node children). Breakdown:
# -   0%          0 by direct references (i.e. parent records hard coded step);
# -   0%          0 by indirect references (i.e. parent records "dict" id),
# ```

# %% [markdown]
# 💡 The 32 byte hash which live at the beginning of every entries represent 50% of the total of bytes here.

# %% [markdown]
# ### Objects Kind
#
# The following plot groups the objects into 10 categories:
# - 4 categories for contents, depending on their size,
# - 5 categories for inodes, depending on the size of the node they belong to,
# - 1 extra category for inodes that appear in several categories at once. (No need to overthink that category)
#
# __Each column in such a graph sum to 100%__.

# %%
plot_vertical_bubble_histo('/tmp/tree_of_cycle_445_contracts-index-star-manager.ipynb.csv', 'ekind')

# %% [markdown]
# ### Objects Distance to Commit
#
# The following plot groups the objects into 5 categories, depending on how old they are.
#
# For instance, `<1 cycle away` implies that the objects in that row are less than 1 cycle away from
# the commit in the pack file (i.e. less than 8200 blocks away, less than 3 days away).
#
# The `4 or more cycles away` row is the largest because most objects of a tree are at the beginning of the file, in the "snapshot import" section.

# %%
plot_vertical_bubble_histo('/tmp/tree_of_cycle_445_contracts-index-star-manager.ipynb.csv', 'area_distance_from_origin')

# %% [markdown]
# 💡 While 124k contracts were modified (or added) during the previous cycle, only 5805 "manager" contents were added during the last cycle. Is this the number of new contracts?
